# %% [markdown]
# # <center>Diabetes Prediction using Logistic Regression</center>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# **1.** [**Introduction**](#Section1)<br>
#   - **1.1** [**Maths Behind Logistic Regression**](#Section11)
#   - **1.2** [**Assumptions of Logistic Regression**](#Section12)
#   - **1.3** [**Pros/Cons of Logistic Regression**](#Section13)
#   - **1.4** [**Applications of Logistic Regression**](#Section14)
#
# **2.** [**Problem Statement**](#Section2)<br>
# **3.** [**Installing & Importing Libraries**](#Section3)<br>
#   - **3.1** [**Installing Libraries**](#Section31)
#   - **3.2** [**Upgrading Libraries**](#Section32)
#   - **3.3** [**Importing Libraries**](#Section33)
#
# **4.** [**Data Acquisition & Description**](#Section4)<br>
#   - **4.1** [**Data Information**](#Section41)
#   - **4.2** [**Data Statistics**](#Section42)
#
# **5.** [**Data Pre-processing**](#Section5)<br>
#   - **5.1** [**Pre-Profiling Report**](#Section51)
#   - **5.2** [**Identification & Handling of Missing Data**](#Section52)<br>
#
# **6.** [**Exploratory Data Analysis**](#Section6)<br>
#
# **7.** [**Post Data Processing & Feature Selection**](#Section7)<br>
#   - **7.1** [**Feature Selection**](#Section71)<br>
#   - **7.2** [**Post Profiling Report**](#Section72)<br>
#   - **7.3** [**Encoding the Categorical Data**](#Section73)<br>
#   - **7.4** [**Data Preparation**](#Section74)<br>
#
# **8.** [**Model Development & Evaluation**](#Section8)<br>
#   - **8.1** [**Logistic Regression - Baseline Model**](#Section81)<br>
#   - **8.2** [**Using Trained Model for Prediction**](#Section82)<br>
#   - **8.3** [**Logistic Regression - Model Evaluation**](#Section83)<br>
#
# **9.** [**Conclusion**](#Section9)<br>

# %% [markdown]
# <a id=section1></a>

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
# - Logistic regression is a techinque used for solving the __classification problem__.
#
# - Classification is nothing but a problem of __identifying__ to which of a set of __categories__ a new observation belongs, on the basis of _training dataset_ containing observations (or instances) whose categorical membership is known.
#
# - For example to predict:<br/> __Whether an email is spam (1) or not (0)__ or,<br/> __Whether the tumor is malignant (1) or not (0)<br/>__

# %% [markdown]
# - Both Linear regression and Logistic regression are __supervised learning techinques__. But for the _Regression_ problem the output is __continuous__ unlike the _classification_ problem where the output is __discrete__. <br/>
#  - Logistic Regression is used when the __dependent variable(target) is categorical__.<br/>
#
# - __Sigmoid function__ or logistic function is used as _hypothesis function_ for logistic regression.
#
# - Below is a figure showing the difference between linear regression and logistic regression, also notice that logistic regression produces a logistic curve, which is limited to values between 0 and 1. <br/>
#
# <br>
# <center><img src="https://github.com/insaid2018/Term-2/raw/master/images/linear%20and%20logistic.jpeg" width="500" height="300" /></center>

# %% [markdown]
# <a name = Section11></a>
# ### **1.1 Maths Behind Logistic Regression**
#
# - The __odds__ for an event is the __(probability of an event occuring) / (probability of event not occuring)__:
#
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-2/master/images/odds.png" width="360" height="140" /></center>
#
# - For __Linear regression__: continuous response is modeled as a linear combination of the features: __y = β0 + β1x__<br/>
# - For __Logistic regression__: log-odds of a categorical response being "__true__" (1) is modeled as a linear combination of the features:

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-2/master/images/logit1.png" width="480" height="240" /></center>

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-2/master/images/logit2.png" width="480" height="240" /></center>

# %% [markdown]
# - Shown below is the plot showing **Linear model** and **Logistic model**
#
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-2/master/images/linear%20vs%20logistic.jpeg" width="480" height="240" /></center>

# %% [markdown]
# In other words:
#
# - Logistic regression outputs the __probabilities of a specific class__.
# - Those probabilities can be converted into __class predictions__.
#
#
# The logistic function has some nice properties:
#
# - Takes on an __"S"__ shape
# - Output is bounded between __0 and 1__<br/>
#
#
# We have covered how this works for binary classification problems (two response classes). But what about __multi-class classification problems__ (more than two response classes)?
#
# - Most common solution for classification models is __"one-vs-all"__ (also known as __"one-vs-rest"__): decompose the problem into multiple binary classification problems.
# - __Multinomial logistic regression__ can solve this as a single problem.

# %% [markdown]
# <a name = Section12></a>
# ### **1.2 Assumptions Logistic Regression**
#
# - It assumes that there is **minimal**,or **no multi-collinearity** among the independent variables.
# - It assumes that independent variables are **linearly related** to **log of odds**.
# - It assumes that the **observations are independent** of each other.
# - There is no **influential values(outliers)** in the **continous predictors(independent variables)**.

# %% [markdown]
# <a name = Section13></a>
# ### **1.3 Pros/Cons of Logistic Regression**
#
# **Pros**
#
# - Logistic Regression is **easier to implement**, **interpret**, and **very efficient to train**.
#
# - It can **easily extend to multiple classes**(multinomial regression) and a natural probabilistic view of class predictions.
#
# - It is **very fast at classifying unknown records**.
#
# - It can **interpret model coefficients as indicators of feature importance**.
#
# - **Good accuracy** for many **simple data set**s and it **performs well when the dataset is linearly separable**.
#
# **Cons**
#
# - If the **number of observations is lesser than the number of features, Logistic Regression should not be used**, otherwise, it **may lead to overfitting**.
#
# - Logistic Regression requires **average** or **no multicollinearity between independent variables**.
#
# - It **constructs linear boundaries**.

# %% [markdown]
# <a name = Section14></a>
# ### **1.4 Application of Logistic regression**
#
# <br>
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-2/master/images/app%20og%20log.png" width="500" height="300" /></center>
# <br>
#
# Logistic Regression was used in __biological sciences__ in early twentieth century. It was then used in many social science applications. For instance,
# - The Trauma and Injury Severity Score (TRISS), which is widely used to __predict mortality in injured patients__, was originally developed by Boyd et al. using logistic regression.<br/>
# - Many other medical scales used to __assess severity__ of a patient have been developed using logistic regression.<br/>
# - Logistic regression may be used to __predict the risk of developing a given disease__ (e.g. diabetes; coronary heart disease), based on observed characteristics of the patient (age, sex, body mass index, results of various blood tests, etc.).<br/>
#
# <br>
# Now a days, Logistic Regression have the following applications:
#
# 1. Image segementation and  categorization
#
# 2. Geographic image processing
#
# 3. Handwriting recognition
#
# 4. Detection of  myocardinal infarction
#
# 5. Predict whether a person is depressed or not based on a bag of words from corpus.
#
# <br>
# The reason why logistic regression is widely used despite of the state of the art of deep neural network is that logistic regression is very efficient and does not require too much computational resources, which makes it affordable to run on production.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. About the Data and Problem Statement**
# ---
# **Diabetes mellitus** is a series of metabolic disorders where there is hyperglycemia (i.e., high blood glucose levels) which can be broadly divided into **type 1 diabetes** (patients cannot produce insulin, mainly affecting juveniles), **type 2 diabetes** (patients have insulin resistance) and gestational diabetes (female patients who **while pregnant** can be **less susceptive to insulin**). **Type 2 diabetes is the most prevalent form of diabetes**.
#
# This data set contains information on Native American women from the United States. It has **8 medical diagnostic attributes** and **one target variable (i.e, Outcome)** of **768 female patients** with 34.9% having diabetes (268 patients). The variance for insulin for both categories was quite high. An independent t-test was used to compare the values between diabetic and non-diabetic patients showing that differences occurred for all 8 independent variables.
#
# For example, there is evidence to suggest that the average blood glucose concentration for diabetics mean=142.2 mg/dl (95% CI: 138.6, 145.7) was higher than non-diabetics, mean=110.7 mg/dl (95% CI: 108.5, 112.9); t(766)= 15.67, p < 0.001 at the 95% confidence level.
#
# Our aim is to find out if the patient is **diabetic(1) or not(0) diabetic** using Logistic Regression.
#
# ![Diabetes-Mellitus.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---
# <a name = Section3></a>
# # **3. Installing & Importing Libraries**
# ---

# %% [markdown]
# <a name = Section31></a>
# ### **3.1 Installing Libraries**

# %%
# !pip install -q datascience                   # Package that is required by pandas profiling
# !pip install -q ydata-profiling               # Library to generate basic statistics about data

# %% [markdown]
# <a name = Section32></a>
# ### **3.2 Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell above (3.1) and below (3.2) again after restarting the runtime.

# %%
# !pip install -q --upgrade ydata-profiling

# %% [markdown]
# <a name = Section33></a>
# ### **3.3 Importing Libraries**

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing for panel data analysis
from ydata_profiling import ProfileReport                           # Import Ydata Profiling (To generate Univariate Analysis)
pd.set_option('display.max_columns', None)                          # Unfolding hidden features if the cardinality is high
pd.set_option('display.max_colwidth', None)                         # Unfolding the max feature width for better clearity
pd.set_option('display.max_rows', None)                             # Unfolding hidden data points if the cardinality is high
pd.set_option('mode.chained_assignment', None)                      # Removing restriction over chained assignments operations
pd.set_option('display.float_format', lambda x: '%.5f' % x)         # To suppress scientific notation over exponential values
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface using matplotlib
import seaborn as sns                                               # Importin seaborm library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
from sklearn.metrics import accuracy_score                          # For calculating the accuracy for the model
from sklearn.metrics import precision_score                         # For calculating the Precision of the model
from sklearn.metrics import recall_score                            # For calculating the recall of the model
from sklearn.metrics import precision_recall_curve                  # For precision and recall metric estimation
from sklearn.metrics import confusion_matrix                        # For verifying model performance using confusion matrix
from sklearn.metrics import f1_score                                # For Checking the F1-Score of our model
from sklearn.metrics import roc_curve                               # For Roc-Auc metric estimation
#-------------------------------------------------------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split                # To split the data in training and testing part
from sklearn.linear_model import LogisticRegression                 # To create the Logistic Regression Model
#-------------------------------------------------------------------------------------------------------------------------------
import warnings                                                     # Importing warning to disable runtime warnings
warnings.filterwarnings("ignore")                                   # Warnings will appear only once

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---

# %% [markdown]
# -  Various variables present in the dataset includes:
#
#  `'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'`
#
# - The dataset comprises of __768 observations of 9 columns__. Below is a table showing names of all the columns and their description.

# %% [markdown]
# | Column Name   | Description                                               |
# | ------------- |:-------------                                            :|
# | Pregnancies   |Number of Pregnant women                       |
# | Glucose     | Glucose concentration
# | BloodPressure        | Blood Presssure of women    |
# | SkinThickness         | Skin thickness of women|
# | Insulin          | Insulin concentration                                          |
# | BMI         | Body Mass Index |
# | DiabetesPedigreeFunction        |Family History of Diabetes |
# | Age        | Age of women|
# | Outcome       | Diabetic or not       |

# %%
diabetes_data = pd.read_csv("diabetes.csv")     # Importing data using pd.read_csv

# %% [markdown]
# <a name = Section41></a>
# ### **4.1 Data Information**
#
# - In this section we will see the **information about the types of features**.

# %%
#Observe the data
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin      BMI  \
# 0            6      148             72             35        0 33.60000
# 1            1       85             66             29        0 26.60000
# 2            8      183             64              0        0 23.30000
# 3            1       89             66             23       94 28.10000
# 4            0      137             40             35      168 43.10000
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                   0.62700   50        1
# 1                   0.35100   31        0
# 2                   0.67200   32        1
# 3                   0.16700   21        0
# 4                   2.28800   33        1

# %%
print("Shape of our Data is :", diabetes_data.shape)
# Out:
# Shape of our Data is : (768, 9)

# %% [markdown]
# - This dataset contains 768 rows and 9 columns

# %% [markdown]
# - Checking for any categorical variable-

# %%
categorical = [var for var in diabetes_data.columns if diabetes_data[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))
print('The categorical variables are :', categorical)
# Out:
# There are 0 categorical variables
#
# The categorical variables are : []

# %%
diabetes_data.info(verbose = True, memory_usage='deep', null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# <a name = Section42></a>
# ### **4.2 Data Statistics**
#
# - In this section we will get **information about the data** and see some observations.

# %%
diabetes_data.describe()
# Out:
#        Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin  \
# count    768.00000 768.00000      768.00000      768.00000 768.00000
# mean       3.84505 120.89453       69.10547       20.53646  79.79948
# std        3.36958  31.97262       19.35581       15.95222 115.24400
# min        0.00000   0.00000        0.00000        0.00000   0.00000
# 25%        1.00000  99.00000       62.00000        0.00000   0.00000
# 50%        3.00000 117.00000       72.00000       23.00000  30.50000
# 75%        6.00000 140.25000       80.00000       32.00000 127.25000
# max       17.00000 199.00000      122.00000       99.00000 846.00000
#
#             BMI  DiabetesPedigreeFunction       Age   Outcome
# count 768.00000                 768.00000 768.00000 768.00000
# mean   31.99258                   0.47188  33.24089   0.34896
# std     7.88416                   0.33133  11.76023   0.47695
# min     0.00000                   0.07800  21.00000   0.00000
# ...

# %% [markdown]
# **Observation:**
#
# - We can see that `Glucose`, `BloodPressure`, `SkinThickness`, `Insulin` and `BMI` have **min values of 0** which are **not real clinical values**. A value of 0 for Pregnancies is a real value.
# - Higher is the age, there's a high chance of getting diabetes.

# %% [markdown]
# <a name = Section5></a>
#
# ---
# # **5. Data Pre-Processing**
# ---

# %% [markdown]
# <a name = Section51></a>
# ### **5.1 Pre-Profiling Report**
#
# - For **quick analysis** pandas profiling is very handy.
#
# - Generates profile reports from a pandas DataFrame.
#
# - For each column **statistics** are presented in an interactive HTML report.

# %%
profile = ProfileReport(df = diabetes_data)
profile.to_file(output_file = 'Pre_Profiling_Report_on_Diabetes_Dataset.html')
print('Accomplished!')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Accomplished!

# %% [markdown]
# **Uncomment and run** the below to generate the profiling report.

# %%
# from google.colab import files                   # Use only if you are using Google Colab, otherwise remove it
# files.download('Pre Profiling Report.html')      # Use only if you are using Google Colab, otherwise remove it

# %% [markdown]
# **Observation:**
#
#
# - Reports shows that the **number of variables**	in our data is **9**.
#
# - **Number of observations(rows)** is	768
#
# - Duplicate rows is **0**
#
# - **No NaN/null/missing** values in the data
#
# - For full details checkout the report.

# %% [markdown]
# <a name = Section52></a>
# ### **5.2 Identification & Handling of Missing Data**
#
# - In this section we will **analyze** and **identify** **missing information** such as **null data** and **zero data**.
#
#
# **Checking for missing data-**

# %%
Sum = diabetes_data.isnull().sum()
Percentage = (diabetes_data.isnull().sum()/diabetes_data.isnull().count())

pd.concat([Sum,Percentage], axis = 1, keys = ['Sum', 'Percentage'])
# Out:
#                           Sum  Percentage
# Pregnancies                 0     0.00000
# Glucose                     0     0.00000
# BloodPressure               0     0.00000
# SkinThickness               0     0.00000
# Insulin                     0     0.00000
# BMI                         0     0.00000
# DiabetesPedigreeFunction    0     0.00000
# Age                         0     0.00000
# Outcome                     0     0.00000

# %% [markdown]
# **Observation:**
#
# - There are no categorical variables
# - There are no missing values

# %% [markdown]
# - Even though the data has no null values, it has zero values which are not feasible.
#
# **Checking the count of non-feasible zero values-**

# %%
for i in ['Glucose','BloodPressure','SkinThickness','Insulin', 'BMI']:
  print(f'Number of 0s in {i}:', diabetes_data[i].isin([0]).sum())
# Out:
# Number of 0s in Glucose: 5
# Number of 0s in BloodPressure: 35
# Number of 0s in SkinThickness: 227
# Number of 0s in Insulin: 374
# Number of 0s in BMI: 11

# %%
for i in ['Glucose','BloodPressure','SkinThickness','Insulin', 'BMI']:
  percent = (diabetes_data[i].isin([0]).sum()/768)*100
  print(f'Percentage of missing data in {i}: {percent: .2f}%')
# Out:
# Percentage of missing data in Glucose:  0.65%
# Percentage of missing data in BloodPressure:  4.56%
# Percentage of missing data in SkinThickness:  29.56%
# Percentage of missing data in Insulin:  48.70%
# Percentage of missing data in BMI:  1.43%

# %% [markdown]
# - Missing value **imputation for numerical features can be done using the mean or the median**.
# - **Mean** is used to **impute the missing values** for the **feature that is normally distributed**.
# - **Median** is used to **impute missing values in highly skewed features**.

# %%
# Making a copy of data set before making minor wrangling operations as we don't want to edit our raw data
df_clean= diabetes_data.copy()

# %%
for i in ['Glucose','BloodPressure','SkinThickness','Insulin', 'BMI']:
  df_clean[i] = df_clean[i].replace(0, diabetes_data[i].mean())

# %%
for i in ['Glucose','BloodPressure','SkinThickness','Insulin', 'BMI']:
  percent = (df_clean[i].isin([0]).sum()/768)*100
  print(f'Percentage of missing data in {i}: {percent: .2f}%')
# Out:
# Percentage of missing data in Glucose:  0.00%
# Percentage of missing data in BloodPressure:  0.00%
# Percentage of missing data in SkinThickness:  0.00%
# Percentage of missing data in Insulin:  0.00%
# Percentage of missing data in BMI:  0.00%

# %% [markdown]
# - Hence we successfully dealt with the zero data

# %% [markdown]
# <a name = Section6></a>
#
# ---
# # **6. Exploratory Data Analysis**
# ---

# %% [markdown]
# **<h4>Taking a look at the label column</h4>**
# - The label column or target variable is the `Outcome` column.
# - **1** signifies presence of Diabetes, **0** signifies absence

# %%
df_clean['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
fig = plt.figure(figsize = [15, 8])
plt.subplot(1, 2, 1)
sns.countplot(x = 'Outcome', data = df_clean)
plt.xlabel(xlabel = 'Outcome', size = 14)
plt.ylabel(ylabel = 'Count', size = 14)
plt.title(label = 'Frequency Distribution', size = 14)

plt.subplot(1, 2, 2)
space = np.ones(2)/10
df_clean['Outcome'].value_counts().plot(kind = 'pie', explode = space, fontsize = 14, autopct = '%3.1f%%', wedgeprops = dict(width=0.15),
                                       startangle = 160, figsize = [15, 8], legend = True)
plt.legend(['Non Diabetic', 'Diabetic'])
plt.ylabel(ylabel = 'Outcome', size = 14)
plt.title(label = 'Proportion Distribution', size = 14)
plt.tight_layout(pad = 3.0)
plt.suptitle(t = 'Frequency & Proportion of having Diabetes', y = 1.02, size = 16)
plt.show()

# %% [markdown]
# **Observation:**
#
# - We can observe that there are 34.9% of people that are **Diabetic**.
#
# - Additionally, we can **observe class imbalance** in our data set.

# %% [markdown]
# **<h4>Looking at a high level overview of the data separated out by outcome, i.e. 1 = diabetes and 0 = no diabetes</h4>**

# %%
sns.pairplot(df_clean, diag_kind='kde', hue='Outcome')

# %%
f,ax=plt.subplots(3,3,figsize=(25, 10),constrained_layout = True)
sns.distplot(df_clean["Pregnancies"],bins=20,ax=ax[0,0])

sns.distplot(df_clean["Glucose"],bins=20,ax=ax[0,1])

sns.distplot(df_clean["BloodPressure"],bins=20,ax=ax[0,2])

sns.distplot(df_clean["SkinThickness"],bins=20,ax=ax[1,0])

sns.distplot(df_clean["Insulin"],bins=20,ax=ax[1,1])

sns.distplot(df_clean["BMI"],bins=20,ax=ax[1,2])

sns.distplot(df_clean["DiabetesPedigreeFunction"],bins=20,ax=ax[2,0])

sns.distplot(df_clean["Age"],bins=20,ax=ax[2,1])

sns.distplot(df_clean["Outcome"],bins=20,ax=ax[2,2])
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Density'>

# %% [markdown]
# **Observation:**
#
# - The overall distribution of `Pregnancies` is centered around lower numbers. Pregnant women have **higher** chnaces of diabetes.
#
# - `Skin thickness` is sometimes used to estimate the amount of body fat a person has, the distribution is centered **higher among the diabetics.**
# -`Body Mass Index (BMI)` is another measure used to estimate body fat, again the plots show the distribution of BMI is centered around a larger number among diabetics.
# - The diabetic group seems to be generally older in `Age` than the non-diabetic group.
# - Levels of `Insulin` were generally higher among diabetics in the data.
# - Blood `Glucose` levels seem to be higher among diabetics in the data.

# %% [markdown]
# **<h4>Relationship between Features</h4>**

# %% [markdown]
# **1. BMI and Skin Thickness**

# %%
plt.figure(figsize = [12, 8])
sns.scatterplot(x= df_clean["BMI"], y= df_clean["SkinThickness"])
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='SkinThickness'>

# %% [markdown]
# **Observation:**
#
# Unsurprisingly there is a positive correlation between BMI and Skin Thickness as they are both used to estimate the amount of body fat a person has. The relationship between the two variables does not seem to differ by diabetic status.

# %% [markdown]
# **2. Glucose and Insulin**

# %%
plt.figure(figsize = [12, 8])
sns.scatterplot(x= df_clean["Glucose"], y= df_clean["Insulin"])
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Insulin'>

# %% [markdown]
# **Observation:**
#
# - There seems to be a positive correlation between insulin and glucose levels.

# %% [markdown]
# <a name = Section7></a>
#
# ---
# # **7. Post Data Processing & Feature Selection**
# ---
# - Now we will **perform encoding of the categorical columns** and **feed it** to the **LogisticRegression**.

# %% [markdown]
# <a name = Section71></a>
# ### **7.1 Feature Selection**
#
# - Here we will **visualize  the correlation** of input features **using Heatmap**.
# - If we see a case of correlation we will **remove the highly correlated feature**.

# %%
plt.figure(figsize = [16, 12])
sns.heatmap(df_clean.corr(), annot = True, fmt = '.3f');
plt.title('Correlation between features')
# Out:
# Text(0.5, 1.0, 'Correlation between features')

# %% [markdown]
# **Observation:**
#
# - We can see that most of the variables are **positively correlated**, though **weakly**.
# - As shown in the scatterplots earlier, insulin and glucose are correlated as are BMI and skin thickness.

# %% [markdown]
# <a name = Section72></a>
# ### **7.2 Post-Profiling Report**
#
# - After doing **missing value Imputation**, we will now look at the report again.

# %%
profile = ProfileReport(df = df_clean)
profile.to_file(output_file = 'Post_Profiling_Report_on_Diabetes_Dataset.html')
print('Accomplished!')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Accomplished!

# %%
# from google.colab import files                   # Use only if you are using Google Colab, otherwise remove it
# files.download('Pre Profiling Report.html')      # Use only if you are using Google Colab, otherwise remove it

# %% [markdown]
# **Observation:**
#
#
# - For full details after the data processing checkout the report.

# %% [markdown]
# <a name = Section73></a>
# ### **7.3 Encoding Categorical Features**

# %%
df_clean.dtypes #Checking for data types of features
# Out:
# Pregnancies                   int64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# As no feature is categorical, there's no need of encoding

# %% [markdown]
# <a name = Section74></a>
# ### **7.4 Data Preparation**
#
# - Now we will **split** our **data** in **training** and **testing** part for further development.

# %%
X = df_clean.drop('Outcome',axis = 1)
y = df_clean['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42, stratify = y)

print('Training Data Shape:', X_train.shape, y_train.shape)
print('Testing Data Shape:', X_test.shape, y_test.shape)
# Out:
# Training Data Shape: (691, 8) (691,)
# Testing Data Shape: (77, 8) (77,)

# %% [markdown]
# <a name = Section8></a>
#
# ---
# # **8. Model Development & Evaluation**
# ---
#
# - In this section we will **develop Logistic Regression using input features** and **tune** our **model if required**.
#
# - Then we will **analyze the results** obtained and **make our observation**.
#
# - For **evaluation purpose** we will **focus** on **Accuracy**, also we will check for **Precision**, **Recall**, **F1-Score**, **Roc-Auc-Curve** and **Precision-Recall Score**.

# %% [markdown]
# <a name = Section81></a>
#
# ## **8.1 Logistic Regression - Baseline Model**

# %%
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# <a name = Section82></a>
#
# ## **8.2 Using Trained Model for Prediction**

# %%
#predicting on train data
y_pred_train = logreg.predict(X_train)

#predicting on test data
y_pred_test = logreg.predict(X_test)

# %% [markdown]
# <a name = Section83></a>
#
# ## **8.3 Logistic Regression Model Evaluation**

# %% [markdown]
# ### Checking Confusion Matrix
# - A __confusion matrix__ is a __summary__ of prediction results on a classification problem.
#
# - The **number of correct and incorrect predictions** are summarized with count values and **broken down by each class**. <br/>
# Below is a diagram showing a general confusion matrix.
#
# <center><img src="https://raw.githubusercontent.com/insaid2018/Term-2/master/images/confusion%20total%20matrix.png" width="500" height="300" /></center>

# %% [markdown]
# - **True Positive (TP)** : Observation is positive, and is predicted to be positive.
# - **False Negative (FN)** : Observation is positive, but is predicted negative.
# - **True Negative (TN)** : Observation is negative, and is predicted to be negative.
# - **False Positive (FP)** : Observation is negative, but is predicted positive.

# %%
cm= confusion_matrix(y_test, y_pred_test)
confusion_matrix = pd.DataFrame(cm)
confusion_matrix.index = ['Actual Non-Diabetic','Actually Diabetic']
confusion_matrix.columns = ['Predicted Non-Diabetic','Predicted Diabetic']
print(confusion_matrix)
# Out:
#                      Predicted Non-Diabetic  Predicted Diabetic
# Actual Non-Diabetic                      43                   7
# Actually Diabetic                        11                  16

# %% [markdown]
# **Observations**
# - True Positive(TP) = 42
# - True Negative(TN) = 15
# - False Positive(FP) = 12
# - False Negative(FN) = 8

# %% [markdown]
# ### Model Evaluation and ROC Curve

# %% [markdown]
# **The Evaluation Metrics**
#
# **Precision** — measures how precise the predictions are.
#
# **Recall** — indicates what percentage of the classes we’re interested in were actually captured by the model.
#
# **Accuracy** is probably the most intuitive metric. We use it to measure the total number of predictions a model gets right, including both True Positives and True Negatives.
#
# **F1 score** is a measurement that considers both precision and recall to compute the score. It can be interpreted as a weighted average of the precision and recall values and cannot be high without both precision and recall also being high. When a model’s F1 score is high, you know that your model is doing well all around.

# %%
print('Accuracy score for test data is:', accuracy_score(y_test,y_pred_test))
# Out:
# Accuracy score for test data is: 0.7662337662337663

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83        50
#            1       0.70      0.59      0.64        27
#
#     accuracy                           0.77        77
#    macro avg       0.75      0.73      0.73        77
# weighted avg       0.76      0.77      0.76        77

# %% [markdown]
# **ROC Curve**
#
# When evaluating models we want to visualize an ROC Curve.
# Illustrating the true positive rate against the false positive rate of our classifier.
#
# **True positive rate** is another name for recall which is a ratio of the true positive predictions compared to all values that are actually positive.
#
# `TPR = TP/(TP+FN)`
#
# **False positive rates** is the ratio of false positive predictions compared to all values that are actually negative.
#
# `FPR = FP/(FP+TN)`
#
# If TPR is our y-axis and FPR is our x-axis, we want our ROC curve to hug the left side of our chart meaning higher the TPR the lower the FPR.
#
# ![1_jvRmmKhpiUOc17V9vFdWgQ.webp](data:image/webp;base64,...)

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = logreg.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)


import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# AUC stands for "**Area Under the Curve**" and is typically used as a metric to evaluate the performance of a binary classification model. The AUC represents the **probability** that a randomly selected positive example is **ranked higher** than a randomly selected negative example.
#
# An **AUC of 0.82** means that the model has a **good ability** to distinguish between the positive and negative classes, with an overall performance that is better than a random classifier. An AUC score **ranges from 0 to 1**, with a score of 0.5 indicating that the model performs no better than random chance, and a score of 1 indicating perfect performance.
#
# ![1_pk05QGzoWhCgRiiFbz-oKQ.png](data:image/png;base64,...)
#
# However, it's important to note that the interpretation of AUC may vary depending on the specific context and the problem being solved. Additionally, it's important to consider other metrics such as precision, recall, and F1-score **in conjunction with AUC** to get a more complete picture of the model's performance.

# %% [markdown]
# <a name = Section9></a>
#
# ---
# # **9. Conclusion**
# ---
#
# - We **studied in breifly about the data**, its **characteristics** and its **distribution**.
#
# - We **explored** some **questions related** to survive and not survived.
#
# - We **investigated in depth about the features** which to **retain** and which to **discard**.
#
# - We **performed model training**.
#
# - We **observed metrics for our prediction**.
#
# - This **model** now can **help us** in **identifying** the potential candidate for diabetes
